# train loss:1.7271672294778873
# train loss:1.7132115203321399
# train loss:1.6650667791832043
# train loss:1.5724940379911245
# train loss:1.957221752120191
# train loss:1.598428243015099
# train loss:1.5724943135535252
# train loss:1.5430628520365213
# train loss:1.7004753944873061
# train loss:1.4027238234282882
# train loss:1.6333718235897898
# train loss:1.772879803180856
# train loss:1.3472397137134018
# train loss:1.4933598486138404
# train loss:1.6474509735966654
# train loss:1.5982881149977046
# train loss:1.6357178612153274
# train loss:1.469716885961577
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-c6e4e8bf4054> in <module>
#      15                   optimizer='Adam', optimizer_param={'lr':0.001},
#      16                   evaluate_sample_num_per_epoch=1000)
# ---> 17 trainer.train()
#      18
#      19 # パラメータの保存
#
# ~\Documents\Python Scripts\ゼロから作るDeepLearning\common\trainer.py in train(self)
#      69     def train(self):
#      70         for i in range(self.max_iter):
# ---> 71             self.train_step()
#      72
#      73         test_acc = self.network.accuracy(self.x_test, self.t_test)
#
# ~\Documents\Python Scripts\ゼロから作るDeepLearning\common\trainer.py in train_step(self)
#      42         t_batch = self.t_train[batch_mask]
#      43
# ---> 44         grads = self.network.gradient(x_batch, t_batch)
#      45         self.optimizer.update(self.network.params, grads)
#      46
#
# ~\Documents\Python Scripts\ゼロから作るDeepLearning\8章_深層学習\deep_convnet.py in gradient(self, x, t)
#     100     def gradient(self, x, t):
#     101         # forward
# --> 102         self.loss(x, t)
#     103
#     104         # backward
#
# ~\Documents\Python Scripts\ゼロから作るDeepLearning\8章_深層学習\deep_convnet.py in loss(self, x, t)
#      81
#      82     def loss(self, x, t):
# ---> 83         y = self.predict(x, train_flg=True)
#      84         return self.last_layer.forward(y, t)
#      85
#
# ~\Documents\Python Scripts\ゼロから作るDeepLearning\8章_深層学習\deep_convnet.py in predict(self, x, train_flg)
#      77                 x = layer.forward(x, train_flg)
#      78             else:
# ---> 79                 x = layer.forward(x)
#      80         return x
#      81
#
# ~\Documents\Python Scripts\ゼロから作るDeepLearning\common\layers.py in forward(self, x)
#     218         out_w = 1 + int((W + 2*self.pad - FW) / self.stride)
#     219
# --> 220         col = im2col(x, FH, FW, self.stride, self.pad)
#     221         col_W = self.W.reshape(FN, -1).T
#     222
#
# ~\Documents\Python Scripts\ゼロから作るDeepLearning\common\util.py in im2col(input_data, filter_h, filter_w, stride, pad)
#      59     #第一引数：N次元の行列　第二引数：前後の文字詰める量　第三引数：埋め込み方式
#      60     #データ数、チャンネル方向にはパディング０、高さと幅の方向には前後にpad分0パディングする
# ---> 61     img = np.pad(input_data, [(0,0), (0,0), (pad, pad), (pad, pad)], 'constant')
#      62     col = np.zeros((N, C, filter_h, filter_w, out_h, out_w))
#      63
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraypad.py in pad(array, pad_width, mode, **kwargs)
#    1244         for axis, ((pad_before, pad_after), (before_val, after_val)) \
#    1245                 in enumerate(zip(pad_width, kwargs['constant_values'])):
# -> 1246             newmat = _prepend_const(newmat, pad_before, before_val, axis)
#    1247             newmat = _append_const(newmat, pad_after, after_val, axis)
#    1248
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraypad.py in _prepend_const(arr, pad_amt, val, axis)
#     131     padshape = tuple(x if i != axis else pad_amt
#     132                      for (i, x) in enumerate(arr.shape))
# --> 133     return _do_prepend(arr, np.full(padshape, val, dtype=arr.dtype), axis)
#     134
#     135
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraypad.py in _do_prepend(arr, pad_chunk, axis)
#      97 def _do_prepend(arr, pad_chunk, axis):
#      98     return np.concatenate(
# ---> 99         (pad_chunk.astype(arr.dtype, copy=False), arr), axis=axis)
#     100
#     101
#
# KeyboardInterrupt:
